# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from keras.models import Sequential
import tensorflow as tf
from keras.layers import Dense
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.layers import Dropout
from keras.layers import LSTM, Dense
from keras.layers import GRU 
def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))

# %%
exchange_data = pd.read_csv('GBPUSDDaily.csv')
exchange_data.head()
# Out:
#                          Local time     Open     High      Low    Close  \
# 0  03.05.2003 22:00:00.000 GMT+0100  1.60377  1.60377  1.60377  1.60377
# 1  04.05.2003 22:00:00.000 GMT+0100  1.60377  1.60751  1.60148  1.60587
# 2  05.05.2003 22:00:00.000 GMT+0100  1.60584  1.61860  1.60462  1.61343
# 3  06.05.2003 22:00:00.000 GMT+0100  1.61275  1.61610  1.59017  1.59591
# 4  07.05.2003 22:00:00.000 GMT+0100  1.59591  1.60773  1.59200  1.60126
#
#         Volume
# 0       0.0000
# 1  136090.6743
# 2  134184.0587
# 3  134451.5214
# 4  133992.2250

# %%
exchange_data["Local time"] = pd.to_datetime(exchange_data["Local time"])
#ind_exchange_data = exchange_data.set_index(["Local time"], drop=True)

# %%
exchange_data["Local time"] = pd.to_datetime(exchange_data["Local time"], utc=True)

# %%
exchange_data["Local time"] = exchange_data[~exchange_data['Local time'].dt.dayofweek.isin([4,5])]

# %%
exchange_data = exchange_data.dropna()

# %%
print(len(exchange_data))
# Out:
# 4887

# %%
ind_exchange_data = exchange_data.set_index(["Local time"], drop=True)

# %%
ind_exchange_data.head()
# Out:
#                               Open     High      Low    Close       Volume
# Local time
# 2003-03-05 23:00:00+00:00  1.60377  1.60377  1.60377  1.60377       0.0000
# 2003-05-05 23:00:00+00:00  1.60584  1.61860  1.60462  1.61343  134184.0587
# 2003-06-05 23:00:00+00:00  1.61275  1.61610  1.59017  1.59591  134451.5214
# 2003-08-05 23:00:00+00:00  1.60135  1.60934  1.60019  1.60370  135567.3534
# 2003-10-05 23:00:00+00:00  1.60370  1.60370  1.60370  1.60370       0.0000

# %%
df = ind_exchange_data[["Close"]]
df.plot(kind='line',figsize=(14,15))
# Out:
# <AxesSubplot:xlabel='Local time'>

# %%
diff = df.index.values[-1] - df.index.values[0]



days = diff.astype('timedelta64[D]')
days = days / np.timedelta64(1, 'D')
years = int(days/365)
print("Total data: %d years"%years)
print("80 percent data = 2010 to %d"%(2010 + int(0.8*years)))
# Out:
# Total data: 18 years
# 80 percent data = 2010 to 2024

# %%
data_frame = np.array(df)
x = int(len(data_frame))
print(x)
split_length = int(len(data_frame) * 0.8)
# Out:
# 4887

# %%
#dates = exchange_data['Local time']


split_date = pd.Timestamp(exchange_data['Local time'].iloc[split_length])

train = df.loc[:split_date]
test = df.loc[split_date:]

ax = train.plot(kind='line',figsize=(14,8))
test.plot(ax=ax,kind='line',figsize=(14,8))
plt.legend(['train', 'test'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)

# %%
X_train = train_sc[:-1]
y_train = train_sc[1:]

X_test = test_sc[:-1]
y_test = test_sc[1:]

# %%
K.clear_session()

model = Sequential()
model.add(Dense(12, input_dim=1, activation='relu'))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 12)                24
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.metrics.mean_squared_error,
              metrics=[tf.keras.metrics.RootMeanSquaredError(name='rmse')], optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=2, verbose=1)
history = model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/200
# 3909/3909 [==============================] - 2s 534us/step - loss: 0.0040 - rmse: 0.0630
# Epoch 2/200
# 3909/3909 [==============================] - 2s 537us/step - loss: 0.0029 - rmse: 0.0537
# Epoch 3/200
# 3909/3909 [==============================] - 2s 525us/step - loss: 0.0028 - rmse: 0.0525
# Epoch 4/200
# 3909/3909 [==============================] - 2s 519us/step - loss: 0.0027 - rmse: 0.0523
# Epoch 5/200
# 3909/3909 [==============================] - 2s 532us/step - loss: 0.0027 - rmse: 0.0524
# Epoch 6/200
# 3909/3909 [==============================] - 2s 533us/step - loss: 0.0027 - rmse: 0.0523
# Epoch 7/200
# 3909/3909 [==============================] - 2s 522us/step - loss: 0.0027 - rmse: 0.0522
# Epoch 8/200
# 3909/3909 [==============================] - 2s 524us/step - loss: 0.0027 - rmse: 0.0521
# Epoch 9/200
# 3909/3909 [==============================] - 2s 538us/step - loss: 0.0027 - rmse: 0.05240s - los
# Epoch 10/200
# 3909/3909 [==============================] - 2s 505us/step - loss: 0.0028 - rmse: 0.0525
# Epoch 00010: early stopping

# %%
#y pred_test is the actual ANN predictions
y_pred_test = model.predict(X_test)
y_train_pred = model.predict(X_train)

train_mse = metrics.mean_squared_error(y_train, y_train_pred)
rmse_train = np.sqrt(train_mse)

test_mse = metrics.mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(test_mse)

print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(y_train, y_train_pred)))
print("The  MAE on the Train set is:\t{:0.3f}".format(metrics.mean_absolute_error(y_train, y_train_pred)))

print("The  RMSE on the Train set is:\t{:0.3f}".format(rmse_train))
r2_train = r2_score(y_train, y_train_pred)
print("The Adjusted R2 score on the Train set is:\t{:0.3f}\n".format(adj_r2_score(r2_train, X_train.shape[0], X_train.shape[1])))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(y_test, y_pred_test)))
r2_test = r2_score(y_test, y_pred_test)
print("The Adjusted R2 score on the Test set is:\t{:0.3f}".format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))
print("The  MAE on the Test set is:\t{:0.3f}".format(metrics.mean_absolute_error(y_test, y_pred_test)))
print("The  RMSE on the Test set is:\t{:0.3f}".format(rmse_test))
# Out:
# The R2 score on the Train set is:	0.933
# The  MAE on the Train set is:	0.215
# The  RMSE on the Train set is:	0.260
# The Adjusted R2 score on the Train set is:	0.933
#
# The R2 score on the Test set is:	0.711
# The Adjusted R2 score on the Test set is:	0.711
# The  MAE on the Test set is:	0.113
# The  RMSE on the Test set is:	0.136

# %%
plt.figure(figsize=(12,8))
plt.plot(y_test, label='True')
plt.plot(y_pred_test, label='ANN')
plt.title("ANN's_Prediction")
plt.xlabel('Observation')
plt.ylabel('INR_Scaled')
plt.legend()
plt.show()

# %%
#Test is with future predictions 


last_value_ann = X_test[-1:]


future_predictions_ann = []
num_steps = 10

for i in range(num_steps):
    prediction_ann = model.predict(last_value_ann.reshape(1,-1))
    
    future_predictions_ann.append(prediction_ann[0][0])
    
    last_value_ann = np.concatenate((last_value_ann[1:], prediction_ann), axis=0)
    

inverse_transformed_data = sc.inverse_transform(future_predictions_ann).flatten().tolist()
print(inverse_transformed_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1026fe9b2a0f> in <module>
#       2
#       3
# ----> 4 last_value_ann = X_test[-1:]
#       5
#       6
#
# NameError: name 'X_test' is not defined
